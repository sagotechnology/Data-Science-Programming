# %% [markdown]
# # Seaborn - Plotting with Python
#
# ### Python and Plotting
# Plotting data is facilitated using a number of tools - python's own drawing tools and a many libraries & plug-ins. In this drill, we explore a number of plot actions for a basis and then integrate data that you manipulate with numpy and pandas.
#
# ### Helpful Tools
# There are lots of helpful tools and demos in GitHub, some of which have been used in this drill set.  Some most common plotting examples: bar plot, scatter, line plots, histograms, and (others).
#
# ### Why visualize?
# The main points of visualizing data is to communicate to the viewer (a) trends in the data, group membership (and when a member of one group intersects with another), unusual "events" or "interesting events" that warrant futher investigation, and an understanding of both the big picture of the data and the subsets (or clusters, classifications) that collectively tell a compelling story.  Adding interactivity either programmatically moving the data over a timeline or letting the user select details-on-demand really underscores the communicative goal of your cool programming.

# %% [markdown]
# ## Data prep
#
# 1) Import numpy, pandas, matplotlib and seaborn
# 2) Load the file "travelData.csv" - this is a file of world travel data from the The World Bank https://data.worldbank.org/indicator/ST.INT.ARVL.
#
# 3) Do some quick exploration of the data like what are the columns and rows?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# %%
df = pd.read_csv('travelData.csv')
df.head()
df.shape
# Out:
# (220, 26)

# %% [markdown]
# ### Bar Chart
#
# Use Seaborn to make a bar chart showing the top 10 countries with the most travelers for the year 2016.

# %%
df2016 = df[['Country_Name', '2016']]
#df2016.sort_values(['2016'], ascending = False, inplace =True)
df2016sort = df2016.sort_values(['2016'], ascending = False)
df2016sort.head(10)
df2016sort.drop([58, 140], inplace = True)

# %%
df2016sort.head(10)
# Out:
#        Country_Name        2016
# 65           France  82570000.0
# 206   United States  75608000.0
# 60            Spain  75315000.0
# 36            China  59270000.0
# 96            Italy  52372000.0
# 69   United Kingdom  35814000.0
# 50          Germany  35555000.0
# 126          Mexico  35079000.0
# 193        Thailand  32530000.0
# 200          Turkey  30289000.0

# %%
df10 = df.nlargest(10, '2016')
# Out:
#        Country_Name Code                             Indicator_Name  \
# 58        Euro area  EMU  International tourism, number of arrivals
# 140   North America  NAC  International tourism, number of arrivals
# 65           France  FRA  International tourism, number of arrivals
# 206   United States  USA  International tourism, number of arrivals
# 60            Spain  ESP  International tourism, number of arrivals
# 36            China  CHN  International tourism, number of arrivals
# 96            Italy  ITA  International tourism, number of arrivals
# 69   United Kingdom  GBR  International tourism, number of arrivals
# 50          Germany  DEU  International tourism, number of arrivals
# 126          Mexico  MEX  International tourism, number of arrivals
#
#         Ind_Code         1995         1996         1997         1998  \
# 58   ST.INT.ARVL  196847000.0  202466000.0  217627000.0  229558000.0
# 140  ST.INT.ARVL   60637000.0   64165000.0   65816000.0   65617000.0
# 65   ST.INT.ARVL   60033000.0   62406000.0   66591000.0   70109000.0
# 206  ST.INT.ARVL   43318000.0   46489000.0   47767000.0   46377000.0
# 60   ST.INT.ARVL   32971000.0   34027000.0   39553000.0   41892000.0
# 36   ST.INT.ARVL   20034000.0   22765000.0   23770000.0   25073000.0
# 96   ST.INT.ARVL   31052000.0   32943000.0   34692000.0   34933000.0
# 69   ST.INT.ARVL   21719000.0   22936000.0   23215000.0   23710000.0
# 50   ST.INT.ARVL   14847000.0   15205000.0   15837000.0   16511000.0
# 126  ST.INT.ARVL   20241000.0   21395000.0   19351000.0   19392000.0
#
#             1999         2000  ...         2007         2008         2009  \
# 58   240992000.0  255220000.0  ...  293226000.0  290324000.0  277270000.0
# 140   68275000.0   71197000.0  ...   74376000.0   75413000.0   71076000.0
# 65    73147000.0   77190000.0  ...   80853000.0   79218000.0   76764000.0
# 206   48509000.0   51238000.0  ...   56135000.0   58007000.0   55103000.0
# 60    45440000.0   46403000.0  ...   58666000.0   57192000.0   52178000.0
# 36    27047000.0   31229000.0  ...   54720000.0   53049000.0   50875000.0
# 96    36516000.0   41181000.0  ...   43654000.0   42734000.0   43239000.0
# 69    23341000.0   23212000.0  ...   30870000.0   30142000.0   28199000.0
# 50    17116000.0   18983000.0  ...   24421000.0   24884000.0   24220000.0
# 126   19043000.0   20641000.0  ...   21606000.0   22931000.0   22346000.0
#
#             2010         2011         2012         2013         2014  \
# 58   283879000.0  301030000.0  307576000.0  321194000.0  335866000.0
# 140   76461000.0   79071000.0   83233000.0   86290000.0   91783000.0
# 65    76647000.0   80499000.0   81980000.0   83634000.0   83701000.0
# 206   60010000.0   62821000.0   66657000.0   69995000.0   75022000.0
# 60    52677000.0   56177000.0   57464000.0   60675000.0   64939000.0
# 36    55664000.0   57581000.0   57725000.0   55686000.0   55622000.0
# 96    43626000.0   46119000.0   46360000.0   47704000.0   48576000.0
# 69    28295000.0   29306000.0   29282000.0   31063000.0   32613000.0
# 50    26875000.0   28374000.0   30411000.0   31545000.0   32999000.0
# 126   23290000.0   23403000.0   23403000.0   24151000.0   29346000.0
#
#             2015         2016
# 58   351169000.0  364655000.0
# 140   95656000.0   95676000.0
# 65    84452000.0   82570000.0
# 206   77465000.0   75608000.0
# 60    68175000.0   75315000.0
# 36    56886000.0   59270000.0
# 96    50732000.0   52372000.0
# 69    34436000.0   35814000.0
# 50    34970000.0   35555000.0
# 126   32093000.0   35079000.0
#
# [10 rows x 26 columns]

# %%
plt.figure(figsize = (18, 10))
chart = sns.barplot(x = 'Country_Name', y = '2016', data = df2016sort.head(10))
chart.set_xticklabels(chart.get_xticklabels(),rotation=45)
sns.set_context('notebook')
chart

# %% [markdown]
# ### Scatterplot
#
# Let's add some more data to our analysis - load the file named 'ruralPop.csv'.
#
# Using both files, plot a scatterplot with the x-axis being the rural pop of the nation and the y-axis being the # of travelers from that nation for the year 2016.
#
# - Hint: merge the datasets on the 'Code' / 'Country Code' field

# %%
trav = pd.read_csv('travelData.csv')
pop = pd.read_csv('ruralPop.csv')
display(trav.head(), pop.head())
# Out:
#   Country_Name Code                             Indicator_Name     Ind_Code  \
# 0        Aruba  ABW  International tourism, number of arrivals  ST.INT.ARVL
# 1  Afghanistan  AFG  International tourism, number of arrivals  ST.INT.ARVL
# 2       Angola  AGO  International tourism, number of arrivals  ST.INT.ARVL
# 3      Albania  ALB  International tourism, number of arrivals  ST.INT.ARVL
# 4      Andorra  AND  International tourism, number of arrivals  ST.INT.ARVL
#
#        1995      1996      1997      1998       1999       2000  ...  \
# 0  619000.0  641000.0  650000.0  647000.0   683000.0   721000.0  ...
# 1       NaN       NaN       NaN       NaN        NaN        NaN  ...
# 2    9000.0   21000.0   45000.0   52000.0    45000.0    51000.0  ...
# 3  304000.0  287000.0  119000.0  184000.0   371000.0   317000.0  ...
# 4       NaN       NaN       NaN       NaN  2347000.0  2949000.0  ...
#
#         2007       2008       2009       2010       2011       2012  \
# 0   772000.0   827000.0   813000.0   824000.0   869000.0   904000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   195000.0   294000.0   366000.0   425000.0   481000.0   528000.0
# 3  1062000.0  1247000.0  1711000.0  2191000.0  2469000.0  3156000.0
# 4  2189000.0  2059000.0  1830000.0  1808000.0  2242000.0  2238000.0
#
#         2013       2014       2015       2016
# 0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN
# 2   650000.0   595000.0   592000.0   397000.0
# 3  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2328000.0  2363000.0  2663000.0  2831000.0
#
# [5 rows x 26 columns]
#   Country Name Country Code    Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Rural population    SP.RUR.TOTL    26685.0
# 1  Afghanistan          AFG  Rural population    SP.RUR.TOTL  8241137.0
# 2       Angola          AGO  Rural population    SP.RUR.TOTL  4885711.0
# 3      Albania          ALB  Rural population    SP.RUR.TOTL  1114818.0
# 4      Andorra          AND  Rural population    SP.RUR.TOTL     5572.0
#
#         1961       1962       1963       1964       1965  ...        2007  \
# 0    27297.0    27693.0    27934.0    28108.0    28278.0  ...     56536.0
# 1  8373138.0  8512056.0  8657977.0  8810646.0  8970246.0  ...  20836789.0
# 2  4934184.0  4980158.0  5019278.0  5043512.0  5049018.0  ...   8879762.0
# 3  1146208.0  1180553.0  1214693.0  1248887.0  1282417.0  ...   1517619.0
# 4     5609.0     5616.0     5601.0     5554.0     5482.0  ...      8841.0
#
#          2008        2009        2010        2011        2012        2013  \
# 0     56980.0     57402.0     57891.0     58227.0     58503.0     58811.0
# 1  21257441.0  21714081.0  22257743.0  22904895.0  23632788.0  24404522.0
# 2   9050985.0   9223200.0   9393181.0   9560379.0   9724804.0   9885476.0
# 3   1473922.0   1432259.0   1393502.0   1358266.0   1324613.0   1291587.0
# 4      9221.0      9365.0      9442.0      9442.0      9371.0      9259.0
#
#          2014        2015        2016
# 0     59109.0     59362.0     59576.0
# 1  25165917.0  25877997.0  26530269.0
# 2  10040932.0  10192857.0  10340319.0
# 3   1258985.0   1226200.0   1195854.0
# 4      9156.0      9092.0      9084.0
#
# [5 rows x 61 columns]

# %%
trav2016 = trav[['Country_Name', 'Code', '2016']]
pop2016 = pop[['Country Code', '2016']]

trav2016.columns = ['Country_Name', 'Code', 'Travelers']
pop2016.columns = ['Code', 'Population']

# %%
df = pd.merge(left = trav2016, right = pop2016, on = 'Code', how = 'inner')

# %%
df.head()
# Out:
#   Country_Name Code  Travelers  Population
# 0        Aruba  ABW  1102000.0     59576.0
# 1  Afghanistan  AFG        NaN  26530269.0
# 2       Angola  AGO   397000.0  10340319.0
# 3      Albania  ALB  4070000.0   1195854.0
# 4      Andorra  AND  2831000.0      9084.0

# %%
df.dropna(inplace=True)
df.head()
# Out:
#   Country_Name Code  Travelers  Population
# 0        Aruba  ABW  1102000.0     59576.0
# 2       Angola  AGO   397000.0  10340319.0
# 3      Albania  ALB  4070000.0   1195854.0
# 4      Andorra  AND  2831000.0      9084.0
# 6    Argentina  ARG  5559000.0   3649822.0

# %%
plt.figure(figsize=(12,10))
ax = sns.scatterplot(x='Population', y='Travelers', data=df)

# %% [markdown]
# ### Heatmap
#
# Finally, make a heat map with the top 10 countries (found above in the bar chart) on the y-axis and the years 2000-2016 on the x-axis.

# %%
trav = pd.read_csv('travelData.csv')

# %%
trav2000  = trav.copy()
trav2000.head()
# Out:
#   Country_Name Code                             Indicator_Name     Ind_Code  \
# 0        Aruba  ABW  International tourism, number of arrivals  ST.INT.ARVL
# 1  Afghanistan  AFG  International tourism, number of arrivals  ST.INT.ARVL
# 2       Angola  AGO  International tourism, number of arrivals  ST.INT.ARVL
# 3      Albania  ALB  International tourism, number of arrivals  ST.INT.ARVL
# 4      Andorra  AND  International tourism, number of arrivals  ST.INT.ARVL
#
#        1995      1996      1997      1998       1999       2000  ...  \
# 0  619000.0  641000.0  650000.0  647000.0   683000.0   721000.0  ...
# 1       NaN       NaN       NaN       NaN        NaN        NaN  ...
# 2    9000.0   21000.0   45000.0   52000.0    45000.0    51000.0  ...
# 3  304000.0  287000.0  119000.0  184000.0   371000.0   317000.0  ...
# 4       NaN       NaN       NaN       NaN  2347000.0  2949000.0  ...
#
#         2007       2008       2009       2010       2011       2012  \
# 0   772000.0   827000.0   813000.0   824000.0   869000.0   904000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   195000.0   294000.0   366000.0   425000.0   481000.0   528000.0
# 3  1062000.0  1247000.0  1711000.0  2191000.0  2469000.0  3156000.0
# 4  2189000.0  2059000.0  1830000.0  1808000.0  2242000.0  2238000.0
#
#         2013       2014       2015       2016
# 0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN
# 2   650000.0   595000.0   592000.0   397000.0
# 3  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2328000.0  2363000.0  2663000.0  2831000.0
#
# [5 rows x 26 columns]

# %%
trav2000 = trav.drop(['Code', 'Indicator_Name', 'Ind_Code', '1995', '1996', '1997', '1998', '1999'], axis=1)

# %%
trav2000.head()
# Out:
#   Country_Name       2000       2001       2002       2003       2004  \
# 0        Aruba   721000.0   691000.0   643000.0   642000.0   728000.0
# 1  Afghanistan        NaN        NaN        NaN        NaN        NaN
# 2       Angola    51000.0    67000.0    91000.0   107000.0   194000.0
# 3      Albania   317000.0   354000.0   470000.0   557000.0   645000.0
# 4      Andorra  2949000.0  3516000.0  3387000.0  3138000.0  2791000.0
#
#         2005       2006       2007       2008       2009       2010  \
# 0   733000.0   694000.0   772000.0   827000.0   813000.0   824000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   210000.0   121000.0   195000.0   294000.0   366000.0   425000.0
# 3   748000.0   937000.0  1062000.0  1247000.0  1711000.0  2191000.0
# 4  2418000.0  2227000.0  2189000.0  2059000.0  1830000.0  1808000.0
#
#         2011       2012       2013       2014       2015       2016
# 0   869000.0   904000.0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   481000.0   528000.0   650000.0   595000.0   592000.0   397000.0
# 3  2469000.0  3156000.0  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2242000.0  2238000.0  2328000.0  2363000.0  2663000.0  2831000.0

# %%
trav2000.dropna()
trav2000.drop([58,140], inplace=True)

trav2000_10 = trav2000.sort_values(['2016'], ascending=False).head(10)
trav2000_10
# Out:
#        Country_Name        2000        2001        2002        2003  \
# 65           France  77190000.0  75202000.0  77012000.0  75048000.0
# 206   United States  51238000.0  46927000.0  43581000.0  41218000.0
# 60            Spain  46403000.0  48565000.0  50331000.0  50854000.0
# 36            China  31229000.0  33167000.0  36803000.0  32970000.0
# 96            Italy  41181000.0  39563000.0  39799000.0  39604000.0
# 69   United Kingdom  23212000.0  20982000.0  22307000.0  22787000.0
# 50          Germany  18983000.0  17861000.0  17969000.0  18399000.0
# 126          Mexico  20641000.0  19810000.0  19667000.0  18665000.0
# 193        Thailand   9579000.0  10133000.0  10873000.0  10082000.0
# 200          Turkey   9586000.0  10783000.0  12790000.0  13341000.0
#
#            2004        2005        2006        2007        2008        2009  \
# 65   74433000.0  74988000.0  77916000.0  80853000.0  79218000.0  76764000.0
# 206  46086000.0  49206000.0  50977000.0  56135000.0  58007000.0  55103000.0
# 60   52430000.0  55914000.0  58004000.0  58666000.0  57192000.0  52178000.0
# 36   41761000.0  46809000.0  49913000.0  54720000.0  53049000.0  50875000.0
# 96   37071000.0  36513000.0  41058000.0  43654000.0  42734000.0  43239000.0
# 69   25678000.0  28039000.0  30654000.0  30870000.0  30142000.0  28199000.0
# 50   20137000.0  21500000.0  23569000.0  24421000.0  24884000.0  24220000.0
# 126  20618000.0  21915000.0  21353000.0  21606000.0  22931000.0  22346000.0
# 193  11737000.0  11567000.0  13822000.0  14464000.0  14584000.0  14150000.0
# 200  16826000.0  20273000.0  18916000.0  26122000.0  29792000.0  30187000.0
#
#            2010        2011        2012        2013        2014        2015  \
# 65   76647000.0  80499000.0  81980000.0  83634000.0  83701000.0  84452000.0
# 206  60010000.0  62821000.0  66657000.0  69995000.0  75022000.0  77465000.0
# 60   52677000.0  56177000.0  57464000.0  60675000.0  64939000.0  68175000.0
# 36   55664000.0  57581000.0  57725000.0  55686000.0  55622000.0  56886000.0
# 96   43626000.0  46119000.0  46360000.0  47704000.0  48576000.0  50732000.0
# 69   28295000.0  29306000.0  29282000.0  31063000.0  32613000.0  34436000.0
# 50   26875000.0  28374000.0  30411000.0  31545000.0  32999000.0  34970000.0
# 126  23290000.0  23403000.0  23403000.0  24151000.0  29346000.0  32093000.0
# 193  15936000.0  19230000.0  22354000.0  26547000.0  24810000.0  29923000.0
# 200  31364000.0  34654000.0  35698000.0  37795000.0  39811000.0  39478000.0
#
#            2016
# 65   82570000.0
# 206  75608000.0
# 60   75315000.0
# 36   59270000.0
# 96   52372000.0
# 69   35814000.0
# 50   35555000.0
# 126  35079000.0
# 193  32530000.0
# 200  30289000.0

# %%
trav2000_10.set_index('Country_Name', inplace=True)

# %%
plt.figure(figsize=(12,10))
ax = sns.heatmap(trav2000_10)
ax.set(xlabel='Year', ylabel='Country')
plt.title('Travelers by year per Top 10 Countries')
plt.show()
