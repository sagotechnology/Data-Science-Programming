# %% [markdown]
# The following cells will load the Vegas dataset.

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Vegas = pd.read_csv('vegas.csv')
Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()

# %% [markdown]
# Group the `DataFrame` by hotel.  For each hotel, compute the net promoter score, defined here as the fraction of scores that equal 5, minus the fraction of scores that equal 1, 2, or 3.

# %%
Vegas.groupby(Vegas.hotel_name).agg(lambda x : (x==5).mean() - (x<4).mean())
# Out:
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                        0.00
# Caesars Palace                                            0.04
# Circus Circus Hotel & Casino Las Vegas                   -0.04
# Encore at wynn Las Vegas                                  0.00
# Excalibur Hotel & Casino                                 -0.04
# Hilton Grand Vacations at the Flamingo                   -0.12
# Hilton Grand Vacations on the Boulevard                   0.00
# Marriott's Grand Chateau                                  0.00
# Monte Carlo Resort&Casino                                -0.04
# Paris Las Vegas                                           0.00
# The Cosmopolitan Las Vegas                               -0.04
# The Cromwell                                             -0.17
# The Palazzo Resort Hotel Casino                           0.04
# The Venetian Las Vegas Hotel                             -0.04
# ...

# %%
by_hotel = Vegas.groupby('hotel_name')

# %%
by_hotel['score'].mean()
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %%
display(by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['score'].agg(lambda x : (x==5).mean()))
display(by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['score'].agg(lambda x : (x==4).mean()))
print('3 stars :', by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['score'].agg(lambda x : (x==3).mean()))
# Out:
# 0.08333333333333333
# 0.375
# 3 stars : 0.2916666666666667

# %%
def net_score(var):
